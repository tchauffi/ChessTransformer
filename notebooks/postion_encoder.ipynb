# %%
import chess
from chesstransformer.models.tokenizer.position_tokenizer import PostionTokenizer

# %%
# create a chess board and set it to a specific position
board = chess.Board()

starting_position = "e2e4 e7e5 g1f3 b8c6 f1c4 g8f6"

for move in starting_position.split():
    board.push_uci(move)

print(board)
# Out:
# r . b q k b . r
# p p p p . p p p
# . . n . . n . .
# . . . . p . . .
# . . B . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R

# %% [markdown]
# ## Board encoding example

# %%
encoder = PostionTokenizer()
encoded = encoder.encode(board)
print(f"Encoded: {encoded}")
# Out:
# Encoded: [4, 2, 3, 5, 6, 0, 0, 4, 1, 1, 1, 1, 0, 1, 1, 1, 0, 0, 0, 0, 0, 2, 0, 0, 0, 0, 3, 0, 1, 0, 0, 0, 0, 0, 0, 0, 7, 0, 0, 0, 0, 0, 8, 0, 0, 8, 0, 0, 7, 7, 7, 7, 0, 7, 7, 7, 10, 0, 9, 11, 12, 9, 0, 10]

# %% [markdown]
# ## Board decoding example

# %%
decoded = encoder.decode(encoded)
print(f"Decoded:\n{decoded}")
# Out:
# Decoded:
# r . b q k b . r
# p p p p . p p p
# . . n . . n . .
# . . . . p . . .
# . . B . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R
