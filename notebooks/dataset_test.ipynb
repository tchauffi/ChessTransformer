# %%
from chesstransformer.datasets.h5_lichess_dataset import HDF5ChessDataset

dataset = HDF5ChessDataset("../data/elite_db.h5")
# Out:
# Loaded dataset: 1533352 games with 148071530 total positions
